# %%
# !pip install tqdm

# %%
# !pip install chembl_webresource_client

# %%
import pandas as pd
import numpy as np
from chembl_webresource_client.new_client import new_client

# %%
targets = new_client.activity  # Assign the 'activity' attribute of 'new_client' to the variable 'targets'
target_query = targets.search('antibiotic') # Search for entries in 'targets' that contain the term 'antibiotic' and assign the results to 'target_query'
target = pd.DataFrame.from_dict(target_query) # Convert the search results stored in 'target_query' into a pandas DataFrame and assign it to the variable 'target'
target # Output the DataFrame 'target' to display the search results
# Out:
#      action_type activity_comment  activity_id activity_properties  \
# 0           None               NA     24832617                  []
# 1           None               NA     24832611                  []
# 2           None               NA     24832612                  []
# 3           None               NA     24832618                  []
# 4           None               NA     24832614                  []
# ...          ...              ...          ...                 ...
# 7509        None           435054     17795015                  []
# 7510        None           435018     17794979                  []
# 7511        None           435020     17794981                  []
# 7512        None           435027     17794988                  []
# 7513        None           435041     17795002                  []
#
#      assay_chembl_id                                  assay_description  \
# 0      CHEMBL5143208                Antibiotic activity against Candida
# 1      CHEMBL5143202   Antibiotic activity against Enterococcus faecium
# 2      CHEMBL5143203  Antibiotic activity against Staphylococcus aureus
# 3      CHEMBL5143209  Antibiotic activity against Mycobacterium tube...
# 4      CHEMBL5143205  Antibiotic activity against Acinetobacter baum...
# ...              ...                                                ...
# 7509   CHEMBL3889122  Inhibition Activity Assay: On the day before t...
# 7510   CHEMBL3889122  Inhibition Activity Assay: On the day before t...
# 7511   CHEMBL3889122  Inhibition Activity Assay: On the day before t...
# 7512   CHEMBL3889122  Inhibition Activity Assay: On the day before t...
# 7513   CHEMBL3889122  Inhibition Activity Assay: On the day before t...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             F                    None                   None  BAO_0000375
# 1             F                    None                   None  BAO_0000375
# 2             F                    None                   None  BAO_0000375
# 3             F                    None                   None  BAO_0000375
# 4             F                    None                   None  BAO_0000375
# ...         ...                     ...                    ...          ...
# 7509          B                    None                   None  BAO_0000190
# 7510          B                    None                   None  BAO_0000190
# 7511          B                    None                   None  BAO_0000190
# 7512          B                    None                   None  BAO_0000190
# 7513          B                    None                   None  BAO_0000190
#
#       ...             target_organism                    target_pref_name  \
# 0     ...                     Candida                             Candida
# 1     ...        Enterococcus faecium                Enterococcus faecium
# 2     ...       Staphylococcus aureus               Staphylococcus aureus
# 3     ...  Mycobacterium tuberculosis          Mycobacterium tuberculosis
# 4     ...     Acinetobacter baumannii             Acinetobacter baumannii
# ...   ...                         ...                                 ...
# 7509  ...                Homo sapiens  Nerve growth factor receptor Trk-A
# 7510  ...                Homo sapiens  Nerve growth factor receptor Trk-A
# 7511  ...                Homo sapiens  Nerve growth factor receptor Trk-A
# 7512  ...                Homo sapiens  Nerve growth factor receptor Trk-A
# 7513  ...                Homo sapiens  Nerve growth factor receptor Trk-A
#
#      target_tax_id text_value  toid      type units    uo_units upper_value  \
# 0             5475       None  None  Activity  None        None        None
# 1             1352       None  None  Activity  None        None        None
# 2             1280       None  None  Activity  None        None        None
# 3             1773       None  None  Activity  None        None        None
# 4              470       None  None  Activity  None        None        None
# ...            ...        ...   ...       ...   ...         ...         ...
# 7509          9606       None  None      IC50    nM  UO_0000065        None
# 7510          9606       None  None      IC50    nM  UO_0000065        None
# 7511          9606       None  None      IC50    nM  UO_0000065        None
# 7512          9606       None  None      IC50    nM  UO_0000065        None
# 7513          9606       None  None      IC50    nM  UO_0000065        None
#
#      value
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# ...    ...
# 7509   1.0
# 7510   1.0
# 7511   1.0
# 7512   2.0
# 7513   1.0
#
# [7514 rows x 46 columns]

# %%
# i dropped the columns with value NaN
drop_columns = ['assay_variant_accession','assay_variant_mutation','text_value','toid','upper_value', 'action_type', 'activity_comment', 'data_validity_comment', 'data_validity_description','ligand_efficiency','pchembl_value','standard_text_value','standard_upper_value', 'activity_properties']
target = target.drop(columns=drop_columns)
target
# Out:
#       activity_id assay_chembl_id  \
# 0        24832617   CHEMBL5143208
# 1        24832611   CHEMBL5143202
# 2        24832612   CHEMBL5143203
# 3        24832618   CHEMBL5143209
# 4        24832614   CHEMBL5143205
# ...           ...             ...
# 7509     17795015   CHEMBL3889122
# 7510     17794979   CHEMBL3889122
# 7511     17794981   CHEMBL3889122
# 7512     17794988   CHEMBL3889122
# 7513     17795002   CHEMBL3889122
#
#                                       assay_description assay_type  \
# 0                   Antibiotic activity against Candida          F
# 1      Antibiotic activity against Enterococcus faecium          F
# 2     Antibiotic activity against Staphylococcus aureus          F
# 3     Antibiotic activity against Mycobacterium tube...          F
# 4     Antibiotic activity against Acinetobacter baum...          F
# ...                                                 ...        ...
# 7509  Inhibition Activity Assay: On the day before t...          B
# 7510  Inhibition Activity Assay: On the day before t...          B
# 7511  Inhibition Activity Assay: On the day before t...          B
# 7512  Inhibition Activity Assay: On the day before t...          B
# 7513  Inhibition Activity Assay: On the day before t...          B
#
#      bao_endpoint   bao_format              bao_label  \
# 0     BAO_0000375  BAO_0000218  organism-based format
# 1     BAO_0000375  BAO_0000218  organism-based format
# 2     BAO_0000375  BAO_0000218  organism-based format
# 3     BAO_0000375  BAO_0000218  organism-based format
# 4     BAO_0000375  BAO_0000218  organism-based format
# ...           ...          ...                    ...
# 7509  BAO_0000190  BAO_0000219      cell-based format
# 7510  BAO_0000190  BAO_0000219      cell-based format
# 7511  BAO_0000190  BAO_0000219      cell-based format
# 7512  BAO_0000190  BAO_0000219      cell-based format
# 7513  BAO_0000190  BAO_0000219      cell-based format
#
#                                        canonical_smiles document_chembl_id  \
# 0           C=C/C(C)=C\C/C=C(\C)CCC=C(COC(C)=O)COC(C)=O      CHEMBL5137123
# 1           C=C/C(C)=C\C/C=C(\C)CCC=C(COC(C)=O)COC(C)=O      CHEMBL5137123
# 2           C=C/C(C)=C\C/C=C(\C)CCC=C(COC(C)=O)COC(C)=O      CHEMBL5137123
# 3           C=C/C(C)=C\C/C=C(\C)CCC=C(COC(C)=O)COC(C)=O      CHEMBL5137123
# 4           C=C/C(C)=C\C/C=C(\C)CCC=C(COC(C)=O)COC(C)=O      CHEMBL5137123
# ...                                                 ...                ...
# 7509  O=C(Nc1cnc(Oc2ccc(-c3cnc4[nH]ncc4c3)cc2)nc1)Nc...      CHEMBL3886952
# 7510  Nc1ncc(Cl)cc1-c1ccc(Oc2ccc(NC(=O)Nc3cc(C(F)(F)...      CHEMBL3886952
# 7511  Nc1ncc(F)cc1-c1ccc(Oc2ncc(NC(=O)Nc3cc(C(F)(F)F...      CHEMBL3886952
# 7512  Nc1ncc(F)cc1-c1ccc(Oc2ncc(NC(=O)Nc3cc(C(F)(F)F...      CHEMBL3886952
# 7513  CN(C)c1ccn2ncc(-c3ccc(Oc4ncc(NC(=O)Nc5cc(C(F)(...      CHEMBL3886952
#
#      document_journal  ...  standard_units standard_value target_chembl_id  \
# 0          J Nat Prod  ...            None           None     CHEMBL612867
# 1          J Nat Prod  ...            None           None        CHEMBL357
# 2          J Nat Prod  ...            None           None        CHEMBL352
# 3          J Nat Prod  ...            None           None        CHEMBL360
# 4          J Nat Prod  ...            None           None     CHEMBL614425
# ...               ...  ...             ...            ...              ...
# 7509             None  ...              nM            1.0       CHEMBL2815
# 7510             None  ...              nM            1.0       CHEMBL2815
# 7511             None  ...              nM            1.0       CHEMBL2815
# 7512             None  ...              nM            2.0       CHEMBL2815
# 7513             None  ...              nM            1.0       CHEMBL2815
#
#                  target_organism                    target_pref_name  \
# 0                        Candida                             Candida
# 1           Enterococcus faecium                Enterococcus faecium
# 2          Staphylococcus aureus               Staphylococcus aureus
# 3     Mycobacterium tuberculosis          Mycobacterium tuberculosis
# 4        Acinetobacter baumannii             Acinetobacter baumannii
# ...                          ...                                 ...
# 7509                Homo sapiens  Nerve growth factor receptor Trk-A
# 7510                Homo sapiens  Nerve growth factor receptor Trk-A
# 7511                Homo sapiens  Nerve growth factor receptor Trk-A
# 7512                Homo sapiens  Nerve growth factor receptor Trk-A
# 7513                Homo sapiens  Nerve growth factor receptor Trk-A
#
#      target_tax_id      type units    uo_units  value
# 0             5475  Activity  None        None   None
# 1             1352  Activity  None        None   None
# 2             1280  Activity  None        None   None
# 3             1773  Activity  None        None   None
# 4              470  Activity  None        None   None
# ...            ...       ...   ...         ...    ...
# 7509          9606      IC50    nM  UO_0000065    1.0
# 7510          9606      IC50    nM  UO_0000065    1.0
# 7511          9606      IC50    nM  UO_0000065    1.0
# 7512          9606      IC50    nM  UO_0000065    2.0
# 7513          9606      IC50    nM  UO_0000065    1.0
#
# [7514 rows x 32 columns]

# %%
target = target.dropna(subset=['molecule_pref_name'])
# Deleting rows where the value in the target_organism column is 'Homo sapiens'
target_filtered = target[(target['target_organism'] != 'Homo sapiens') &
                         (target['target_organism'] != 'Mus musculus')]
target_filtered.reset_index(drop=True, inplace=True)
display(target_filtered)
# Out:
#       activity_id assay_chembl_id  \
# 0         1848814    CHEMBL914565
# 1         1848818    CHEMBL914565
# 2         1848819    CHEMBL914565
# 3         1848815    CHEMBL914565
# 4         1848817    CHEMBL914565
# ...           ...             ...
# 1682       277958    CHEMBL673429
# 1683       277957    CHEMBL673433
# 1684      4900495   CHEMBL1614051
# 1685     17777736   CHEMBL3888734
# 1686     17777735   CHEMBL3888734
#
#                                       assay_description assay_type  \
# 0     Increase in ROS levels in Escherichia coli K12...          F
# 1     Increase in ROS levels in Escherichia coli K12...          F
# 2     Increase in ROS levels in Escherichia coli K12...          F
# 3     Increase in ROS levels in Escherichia coli K12...          F
# 4     Increase in ROS levels in Escherichia coli K12...          F
# ...                                                 ...        ...
# 1682  The compound was tested for inhibition of Poly...          F
# 1683  The compound was tested for inhibition of Poly...          F
# 1684  PUBCHEM_BIOASSAY: A Cell Based Secondary Assay...          F
# 1685  Enzymatic Assay: Enzymatic activity is measure...          B
# 1686  Enzymatic Assay: Enzymatic activity is measure...          B
#
#      bao_endpoint   bao_format              bao_label  \
# 0     BAO_0000193  BAO_0000218  organism-based format
# 1     BAO_0000193  BAO_0000218  organism-based format
# 2     BAO_0000193  BAO_0000218  organism-based format
# 3     BAO_0000193  BAO_0000218  organism-based format
# 4     BAO_0000193  BAO_0000218  organism-based format
# ...           ...          ...                    ...
# 1682  BAO_0000201  BAO_0000218  organism-based format
# 1683  BAO_0000201  BAO_0000218  organism-based format
# 1684  BAO_0000187  BAO_0000019           assay format
# 1685  BAO_0000190  BAO_0000357  single protein format
# 1686  BAO_0000190  BAO_0000357  single protein format
#
#                                        canonical_smiles document_chembl_id  \
# 0     CN[C@@H]1[C@H](O[C@H]2[C@H](O[C@H]3[C@H](O)[C@...      CHEMBL1142094
# 1     CNC(C)[C@@H]1CC[C@@H](N)[C@@H](O[C@H]2[C@H](O)...      CHEMBL1142094
# 2     NC[C@H]1O[C@H](O[C@H]2[C@H](O)[C@@H](O[C@H]3O[...      CHEMBL1142094
# 3                                CC1=CC(=O)c2ccccc2C1=O      CHEMBL1142094
# 4            O=C(O)c1cn(C2CC2)c2cc(N3CCNCC3)c(F)cc2c1=O      CHEMBL1142094
# ...                                                 ...                ...
# 1682  CSC[S@@+]([O-])CC(CO)NC(=O)/C=C/c1c(C)[nH]c(=O...      CHEMBL1126976
# 1683  CSC[S@@+]([O-])CC(CO)NC(=O)/C=C/c1c(C)[nH]c(=O...      CHEMBL1126976
# 1684  CCCCCCCCCCCCCCCC[N+](C)(C)CCN(Cc1ccc(OC)cc1)c1...      CHEMBL1201862
# 1685                                    Nc1cccc2cccnc12      CHEMBL3886809
# 1686                                    Oc1cccc2cccnc12      CHEMBL3886809
#
#                  document_journal  ...  standard_units standard_value  \
# 0     Antimicrob Agents Chemother  ...            None           0.78
# 1     Antimicrob Agents Chemother  ...            None            1.0
# 2     Antimicrob Agents Chemother  ...            None           0.87
# 3     Antimicrob Agents Chemother  ...            None           2.02
# 4     Antimicrob Agents Chemother  ...            None            1.1
# ...                           ...  ...             ...            ...
# 1682                   J Med Chem  ...               %           39.4
# 1683                   J Med Chem  ...               %           41.3
# 1684                         None  ...              nM        10615.0
# 1685                         None  ...              nM        79000.0
# 1686                         None  ...              nM       300000.0
#
#      target_chembl_id             target_organism  \
# 0           CHEMBL354            Escherichia coli
# 1           CHEMBL354            Escherichia coli
# 2           CHEMBL354            Escherichia coli
# 3           CHEMBL354            Escherichia coli
# 4           CHEMBL354            Escherichia coli
# ...               ...                         ...
# 1682        CHEMBL354            Escherichia coli
# 1683        CHEMBL354            Escherichia coli
# 1684     CHEMBL612545                        None
# 1685    CHEMBL1287620  Mycobacterium tuberculosis
# 1686    CHEMBL1287620  Mycobacterium tuberculosis
#
#                     target_pref_name target_tax_id        type units  \
# 0                   Escherichia coli           562       Ratio  None
# 1                   Escherichia coli           562       Ratio  None
# 2                   Escherichia coli           562       Ratio  None
# 3                   Escherichia coli           562       Ratio  None
# 4                   Escherichia coli           562       Ratio  None
# ...                              ...           ...         ...   ...
# 1682                Escherichia coli           562  Inhibition     %
# 1683                Escherichia coli           562  Inhibition     %
# 1684                       Unchecked          None        CC50    um
# 1685  Fructose-bisphosphate aldolase          1773        IC50    nM
# 1686  Fructose-bisphosphate aldolase          1773        IC50    nM
#
#         uo_units     value
# 0           None      0.78
# 1           None       1.0
# 2           None      0.87
# 3           None      2.02
# 4           None       1.1
# ...          ...       ...
# 1682  UO_0000187      39.4
# 1683  UO_0000187      41.3
# 1684  UO_0000065    10.615
# 1685  UO_0000065   79000.0
# 1686  UO_0000065  300000.0
#
# [1687 rows x 32 columns]

# %%
target_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1687 entries, 0 to 1686
# Data columns (total 32 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   activity_id                1687 non-null   int64
#  1   assay_chembl_id            1687 non-null   object
#  2   assay_description          1687 non-null   object
#  3   assay_type                 1687 non-null   object
#  4   bao_endpoint               1687 non-null   object
#  5   bao_format                 1687 non-null   object
#  6   bao_label                  1687 non-null   object
#  7   canonical_smiles           1687 non-null   object
#  8   document_chembl_id         1687 non-null   object
#  9   document_journal           1678 non-null   object
#  10  document_year              1680 non-null   float64
#  11  molecule_chembl_id         1687 non-null   object
#  12  molecule_pref_name         1687 non-null   object
#  13  parent_molecule_chembl_id  1687 non-null   object
#  14  potential_duplicate        1687 non-null   int64
#  15  qudt_units                 1524 non-null   object
#  16  record_id                  1687 non-null   int64
#  17  relation                   1562 non-null   object
#  18  src_id                     1687 non-null   int64
#  19  standard_flag              1687 non-null   int64
#  20  standard_relation          1562 non-null   object
#  21  standard_type              1687 non-null   object
#  22  standard_units             1534 non-null   object
#  23  standard_value             1557 non-null   object
#  24  target_chembl_id           1687 non-null   object
#  25  target_organism            1606 non-null   object
#  26  target_pref_name           1687 non-null   object
#  27  target_tax_id              1606 non-null   object
#  28  type                       1687 non-null   object
#  29  units                      1539 non-null   object
#  30  uo_units                   1524 non-null   object
#  31  value                      1557 non-null   object
# dtypes: float64(1), int64(5), object(26)
# memory usage: 250.5+ KB

# %%
target_filtered = target_filtered.drop_duplicates()
target_filtered
# Out:
#       activity_id assay_chembl_id  \
# 0         1848814    CHEMBL914565
# 1         1848818    CHEMBL914565
# 2         1848819    CHEMBL914565
# 3         1848815    CHEMBL914565
# 4         1848817    CHEMBL914565
# ...           ...             ...
# 1682       277958    CHEMBL673429
# 1683       277957    CHEMBL673433
# 1684      4900495   CHEMBL1614051
# 1685     17777736   CHEMBL3888734
# 1686     17777735   CHEMBL3888734
#
#                                       assay_description assay_type  \
# 0     Increase in ROS levels in Escherichia coli K12...          F
# 1     Increase in ROS levels in Escherichia coli K12...          F
# 2     Increase in ROS levels in Escherichia coli K12...          F
# 3     Increase in ROS levels in Escherichia coli K12...          F
# 4     Increase in ROS levels in Escherichia coli K12...          F
# ...                                                 ...        ...
# 1682  The compound was tested for inhibition of Poly...          F
# 1683  The compound was tested for inhibition of Poly...          F
# 1684  PUBCHEM_BIOASSAY: A Cell Based Secondary Assay...          F
# 1685  Enzymatic Assay: Enzymatic activity is measure...          B
# 1686  Enzymatic Assay: Enzymatic activity is measure...          B
#
#      bao_endpoint   bao_format              bao_label  \
# 0     BAO_0000193  BAO_0000218  organism-based format
# 1     BAO_0000193  BAO_0000218  organism-based format
# 2     BAO_0000193  BAO_0000218  organism-based format
# 3     BAO_0000193  BAO_0000218  organism-based format
# 4     BAO_0000193  BAO_0000218  organism-based format
# ...           ...          ...                    ...
# 1682  BAO_0000201  BAO_0000218  organism-based format
# 1683  BAO_0000201  BAO_0000218  organism-based format
# 1684  BAO_0000187  BAO_0000019           assay format
# 1685  BAO_0000190  BAO_0000357  single protein format
# 1686  BAO_0000190  BAO_0000357  single protein format
#
#                                        canonical_smiles document_chembl_id  \
# 0     CN[C@@H]1[C@H](O[C@H]2[C@H](O[C@H]3[C@H](O)[C@...      CHEMBL1142094
# 1     CNC(C)[C@@H]1CC[C@@H](N)[C@@H](O[C@H]2[C@H](O)...      CHEMBL1142094
# 2     NC[C@H]1O[C@H](O[C@H]2[C@H](O)[C@@H](O[C@H]3O[...      CHEMBL1142094
# 3                                CC1=CC(=O)c2ccccc2C1=O      CHEMBL1142094
# 4            O=C(O)c1cn(C2CC2)c2cc(N3CCNCC3)c(F)cc2c1=O      CHEMBL1142094
# ...                                                 ...                ...
# 1682  CSC[S@@+]([O-])CC(CO)NC(=O)/C=C/c1c(C)[nH]c(=O...      CHEMBL1126976
# 1683  CSC[S@@+]([O-])CC(CO)NC(=O)/C=C/c1c(C)[nH]c(=O...      CHEMBL1126976
# 1684  CCCCCCCCCCCCCCCC[N+](C)(C)CCN(Cc1ccc(OC)cc1)c1...      CHEMBL1201862
# 1685                                    Nc1cccc2cccnc12      CHEMBL3886809
# 1686                                    Oc1cccc2cccnc12      CHEMBL3886809
#
#                  document_journal  ...  standard_units standard_value  \
# 0     Antimicrob Agents Chemother  ...            None           0.78
# 1     Antimicrob Agents Chemother  ...            None            1.0
# 2     Antimicrob Agents Chemother  ...            None           0.87
# 3     Antimicrob Agents Chemother  ...            None           2.02
# 4     Antimicrob Agents Chemother  ...            None            1.1
# ...                           ...  ...             ...            ...
# 1682                   J Med Chem  ...               %           39.4
# 1683                   J Med Chem  ...               %           41.3
# 1684                         None  ...              nM        10615.0
# 1685                         None  ...              nM        79000.0
# 1686                         None  ...              nM       300000.0
#
#      target_chembl_id             target_organism  \
# 0           CHEMBL354            Escherichia coli
# 1           CHEMBL354            Escherichia coli
# 2           CHEMBL354            Escherichia coli
# 3           CHEMBL354            Escherichia coli
# 4           CHEMBL354            Escherichia coli
# ...               ...                         ...
# 1682        CHEMBL354            Escherichia coli
# 1683        CHEMBL354            Escherichia coli
# 1684     CHEMBL612545                        None
# 1685    CHEMBL1287620  Mycobacterium tuberculosis
# 1686    CHEMBL1287620  Mycobacterium tuberculosis
#
#                     target_pref_name target_tax_id        type units  \
# 0                   Escherichia coli           562       Ratio  None
# 1                   Escherichia coli           562       Ratio  None
# 2                   Escherichia coli           562       Ratio  None
# 3                   Escherichia coli           562       Ratio  None
# 4                   Escherichia coli           562       Ratio  None
# ...                              ...           ...         ...   ...
# 1682                Escherichia coli           562  Inhibition     %
# 1683                Escherichia coli           562  Inhibition     %
# 1684                       Unchecked          None        CC50    um
# 1685  Fructose-bisphosphate aldolase          1773        IC50    nM
# 1686  Fructose-bisphosphate aldolase          1773        IC50    nM
#
#         uo_units     value
# 0           None      0.78
# 1           None       1.0
# 2           None      0.87
# 3           None      2.02
# 4           None       1.1
# ...          ...       ...
# 1682  UO_0000187      39.4
# 1683  UO_0000187      41.3
# 1684  UO_0000065    10.615
# 1685  UO_0000065   79000.0
# 1686  UO_0000065  300000.0
#
# [1687 rows x 32 columns]

# %%
columns_to_fill = ['document_year']

# Fill missing values with the mode for multiple columns
for column in columns_to_fill:
    mode_value = target_filtered[column].mode()[0]  # Find the mode for the column
    target_filtered[column] = target_filtered[column].fillna(mode_value, inplace=True)  # Fill missing values with the mode
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /lib/python3.12/site-packages/pandas/core/indexes/range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 5
#       3 # Fill missing values with the mode for multiple columns
#       4 for column in columns_to_fill:
# ----> 5     mode_value = target_filtered[column].mode()[0]  # Find the mode for the column
#       6     target_filtered[column] = target_filtered[column].fillna(mode_value, inplace=True)  # Fill missing values with the mode
#
# File /lib/python3.12/site-packages/pandas/core/series.py:1111, in Series.__getitem__(self, key)
#    1108     return self._values[key]
#    1110 elif key_is_scalar:
# -> 1111     return self._get_value(key)
#    1113 # Convert generator to list before going through hashable part
#    1114 # (We will iterate through the generator there to check for slices)
#    1115 if is_iterator(key):
#
# File /lib/python3.12/site-packages/pandas/core/series.py:1227, in Series._get_value(self, label, takeable)
#    1224     return self._values[label]
#    1226 # Similar to Index.get_value, but we do not fall back to positional
# -> 1227 loc = self.index.get_loc(label)
#    1229 if is_integer(loc):
#    1230     return self._values[loc]
#
# File /lib/python3.12/site-packages/pandas/core/indexes/range.py:415, in RangeIndex.get_loc(self, key)
#     413         return self._range.index(new_key)
#     414     except ValueError as err:
# --> 415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
#     417     raise KeyError(key)
#
# KeyError: 0

# %%
target_sorted = target_filtered.sort_values(by='molecule_pref_name', ascending=True)
target_sorted.insert(0, 'molecule_pref_name', target_sorted.pop('molecule_pref_name'))
display(target_sorted)
# Out:
#      molecule_pref_name  activity_id assay_chembl_id  \
# 531   4-HYDROXYCHALCONE     10940204   CHEMBL2049825
# 525   4-HYDROXYCHALCONE     10940205   CHEMBL2049826
# 524   4-HYDROXYCHALCONE     10940203   CHEMBL2049823
# 1685   8-AMINOQUINOLINE     17777736   CHEMBL3888734
# 48             AMIKACIN      1833636    CHEMBL920817
# ...                 ...          ...             ...
# 302          VANCOMYCIN     23190102   CHEMBL4818434
# 1571         VANCOMYCIN     24833193   CHEMBL5143466
# 605          VANCOMYCIN      3542023   CHEMBL1284156
# 262          VANCOMYCIN      6375807   CHEMBL1839958
# 481          VANCOMYCIN     24704994   CHEMBL5108451
#
#                                       assay_description assay_type  \
# 531   Antibacterial activity against methicillin-res...          F
# 525   Antibacterial activity against methicillin-res...          F
# 524   Antibacterial activity against methicillin-sen...          F
# 1685  Enzymatic Assay: Enzymatic activity is measure...          B
# 48    Antibiotic susceptibility by resistance agains...          F
# ...                                                 ...        ...
# 302   Antimicrobial activity against antibiotic-resi...          F
# 1571  Post antibiotic effect against Staphylococcus ...          F
# 605   Bactericidal activity against daptomycin-nonsu...          F
# 262   Antimicrobial activity against methicillin-res...          F
# 481   Antibacterial activity against antibiotic resi...          F
#
#      bao_endpoint   bao_format              bao_label  \
# 531   BAO_0000179  BAO_0000218  organism-based format
# 525   BAO_0000179  BAO_0000218  organism-based format
# 524   BAO_0000179  BAO_0000218  organism-based format
# 1685  BAO_0000190  BAO_0000357  single protein format
# 48    BAO_0001103  BAO_0000218  organism-based format
# ...           ...          ...                    ...
# 302   BAO_0002146  BAO_0000218  organism-based format
# 1571  BAO_0000179  BAO_0000218  organism-based format
# 605   BAO_0000179  BAO_0000218  organism-based format
# 262   BAO_0000190  BAO_0000218  organism-based format
# 481   BAO_0002146  BAO_0000218  organism-based format
#
#                                        canonical_smiles document_chembl_id  \
# 531                       O=C(/C=C/c1ccc(O)cc1)c1ccccc1      CHEMBL2046424
# 525                       O=C(/C=C/c1ccc(O)cc1)c1ccccc1      CHEMBL2046424
# 524                       O=C(/C=C/c1ccc(O)cc1)c1ccccc1      CHEMBL2046424
# 1685                                    Nc1cccc2cccnc12      CHEMBL3886809
# 48    NCC[C@H](O)C(=O)N[C@@H]1C[C@H](N)[C@@H](O[C@H]...      CHEMBL1142216
# ...                                                 ...                ...
# 302   CN[C@H](CC(C)C)C(=O)N[C@H]1C(=O)N[C@@H](CC(N)=...      CHEMBL4814057
# 1571  CN[C@H](CC(C)C)C(=O)N[C@H]1C(=O)N[C@@H](CC(N)=...      CHEMBL5137134
# 605   CN[C@H](CC(C)C)C(=O)N[C@H]1C(=O)N[C@@H](CC(N)=...      CHEMBL1275598
# 262   CN[C@H](CC(C)C)C(=O)N[C@H]1C(=O)N[C@@H](CC(N)=...      CHEMBL1833970
# 481   CN[C@H](CC(C)C)C(=O)N[C@H]1C(=O)N[C@@H](CC(N)=...      CHEMBL5107949
#
#       ... standard_units  standard_value target_chembl_id  \
# 531   ...           None            0.62        CHEMBL352
# 525   ...           None            0.25        CHEMBL352
# 524   ...           None            0.31        CHEMBL352
# 1685  ...             nM         79000.0    CHEMBL1287620
# 48    ...              %            90.9        CHEMBL348
# ...   ...            ...             ...              ...
# 302   ...        ug.mL-1            0.78        CHEMBL352
# 1571  ...             hr             3.5        CHEMBL352
# 605   ...        ug ml-1             2.0        CHEMBL352
# 262   ...        ug.mL-1           12.25        CHEMBL352
# 481   ...        ug.mL-1            0.39        CHEMBL359
#
#                  target_organism                target_pref_name  \
# 531        Staphylococcus aureus           Staphylococcus aureus
# 525        Staphylococcus aureus           Staphylococcus aureus
# 524        Staphylococcus aureus           Staphylococcus aureus
# 1685  Mycobacterium tuberculosis  Fructose-bisphosphate aldolase
# 48        Pseudomonas aeruginosa          Pseudomonas aeruginosa
# ...                          ...                             ...
# 302        Staphylococcus aureus           Staphylococcus aureus
# 1571       Staphylococcus aureus           Staphylococcus aureus
# 605        Staphylococcus aureus           Staphylococcus aureus
# 262        Staphylococcus aureus           Staphylococcus aureus
# 481            Bacillus subtilis               Bacillus subtilis
#
#      target_tax_id      type    units    uo_units    value
# 531           1280      FICI     None        None     0.62
# 525           1280      FICI     None        None     0.25
# 524           1280      FICI     None        None     0.31
# 1685          1773      IC50       nM  UO_0000065  79000.0
# 48             287  Activity        %  UO_0000187     90.9
# ...            ...       ...      ...         ...      ...
# 302           1280       MIC  ug ml-1  UO_0000274     0.78
# 1571          1280      Time       hr  UO_0000032      3.5
# 605           1280       MBC  ug ml-1  UO_0000274      2.0
# 262           1280      IC50  ug ml-1  UO_0000274    12.25
# 481           1423       MIC  ug ml-1  UO_0000274     0.39
#
# [1687 rows x 32 columns]

# %%
# Предположим, что идентификаторы находятся в столбце с именем 'ChEMBL_ID'
chembl_ids = set(target_sorted['molecule_chembl_id'].tolist())
chembl_ids_list = list(chembl_ids)
len(chembl_ids_list)
display(len(chembl_ids_list))
chembl_10 = chembl_ids_list[:10]
chembl_10
# # Создаем объект ресурса
# compounds = new_client.molecule

# # Получаем информацию о соединениях
# compounds_info = [compounds.get(chembl_id) for chembl_id in chembl_ids]

# %%
# Создаем объект ресурса
activity = new_client.activity
res = activity.filter(molecule_chembl_id__in=chembl_10).only('molecule_chembl_id', 'standard_value', 'type')
df_2 = pd.DataFrame(res)
display(df_2)

# %%
# Создаем объект ресурса
activity = new_client.activity

# # Получаем информацию о соединениях с фильтром по стандартному типу IC50
# res = activity.filter(molecule_chembl_id__in=chembl_ids_list)

# # Преобразуем результат в DataFrame
# df_1 = pd.DataFrame(res)


res = activity.filter(molecule_chembl_id__in=chembl_10)
df_1 = pd.DataFrame(res)
# Выводим первые 3 строки таблицы
display(df_1)

# %%
df_1.info()

# %%
# i dropped the columns with value NaN
df_1 = df_1.drop(columns=drop_columns)
df_1

# %%
df_1 = df_1[df_1['target_organism'] != 'Homo sapiens']
df_1
